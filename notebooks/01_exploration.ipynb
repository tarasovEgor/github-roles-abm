# %% [markdown]
# # 01. Загрузка и первичная обработка датасета (EDA)
#
# ---

# %% [markdown]
# > Импорты и настройки:

# %%
import os
import json
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# > Константы:

# %%
DATA_PATH = "/Users/georgetarasov/Desktop/NIR/github-roles-abm/data/data.json"

# %% [markdown]
# > Загрузка датасета:

# %%
def load_large_json(path, max_records=None):
    """
    Универсальная загрузка JSON или JSONL.
    max_records — если нужно ограничить размер (например, 100000).
    """
    data = []
    
    with open(path, "r", encoding="utf-8") as f:
        first_char = f.read(1)
        f.seek(0)
        
        if first_char != "[":
            print("Detected JSONL format")
            for i, line in enumerate(f):
                if max_records and i >= max_records:
                    break
                data.append(json.loads(line))
        else:
            print("Detected single JSON array")
            full_data = json.load(f)
            data = full_data[:max_records] if max_records else full_data

    return pd.DataFrame(data)

# %% [markdown]
# > Загружаем **sample 100k** для **EDA**:

# %%
github_users_100k_df = load_large_json(DATA_PATH, max_records=100_000)
github_users_100k_df.head(5)
# Out:
# Detected JSONL format
#   hirable  public_repos  is_suspicious           updated_at        id blog  \
# 0    None             0          False  2018-02-14 16:37:08   6611157
# 1    None             0          False  2017-10-02 17:43:51  32464022
# 2    None             3           True  2016-02-28 05:00:58  12417299
# 3    None             1           True  2016-05-01 07:19:02  18867538
# 4    None             0          False  2016-02-27 10:52:51   5343442
#
#    followers location follower_list  type commit_list   bio  commits company  \
# 0          0     None            []  User          []  None      0.0    None
# 1          0     None            []  User          []  None      0.0    None
# 2          0     None          None  User        None  None      NaN    None
# 3          0     None          None  User        None  None      NaN    None
# 4          0     None            []  User          []  None      0.0    None
#
#   following_list  public_gists  name           created_at email  following  \
# 0             []             0  None  2014-02-07 01:01:35  None          0
# 1             []             0  None  2017-10-02 17:43:51  None          0
# 2           None             0  None  2015-05-12 19:35:16  None          0
# 3           None             0  None  2016-05-01 07:19:01  None          0
# 4             []             0  None  2013-08-30 02:06:20  None          0
#
#              login repo_list
# 0    lorraine94588        []
# 1  nourelddinayman        []
# 2  joseph5swa6rblo      None
# 3         aborebyg      None
# 4        Frapuchis        []

# %% [markdown]
# > Общая информация:

# %%
github_users_100k_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 22 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   hirable         2208 non-null    object
#  1   public_repos    100000 non-null  int64
#  2   is_suspicious   100000 non-null  bool
#  3   updated_at      100000 non-null  object
#  4   id              100000 non-null  int64
#  5   blog            100000 non-null  object
#  6   followers       100000 non-null  int64
#  7   location        8620 non-null    object
#  8   follower_list   78608 non-null   object
#  9   type            100000 non-null  object
#  10  commit_list     78608 non-null   object
#  11  bio             6381 non-null    object
#  12  commits         78608 non-null   float64
#  13  company         4523 non-null    object
#  14  following_list  78608 non-null   object
#  15  public_gists    100000 non-null  int64
#  16  name            18595 non-null   object
#  17  created_at      100000 non-null  object
#  18  email           6646 non-null    object
#  19  following       100000 non-null  int64
#  20  login           100000 non-null  object
#  21  repo_list       78608 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(15)
# memory usage: 16.1+ MB

# %%
github_users_100k_df.describe()
# Out:
#         public_repos            id      followers       commits  \
# count  100000.000000  1.000000e+05  100000.000000  78608.000000
# mean        1.972590  1.774525e+07       0.466900     14.029844
# std        12.210868  1.001670e+07      14.251944     61.675306
# min         0.000000  1.120000e+03       0.000000      0.000000
# 25%         0.000000  9.144597e+06       0.000000      0.000000
# 50%         0.000000  1.784227e+07       0.000000      0.000000
# 75%         1.000000  2.641695e+07       0.000000      2.000000
# max      2341.000000  3.499142e+07    3154.000000    898.000000
#
#         public_gists      following
# count  100000.000000  100000.000000
# mean        0.164380       0.580780
# std         2.074161      12.526793
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         0.000000       0.000000
# max       183.000000    3366.000000

# %% [markdown]
# > Проверка пропусков:

# %%
github_users_100k_df.isna().mean().sort_values(ascending=False)
# Out:
# hirable           0.97792
# company           0.95477
# bio               0.93619
# email             0.93354
# location          0.91380
# name              0.81405
# commits           0.21392
# commit_list       0.21392
# following_list    0.21392
# repo_list         0.21392
# follower_list     0.21392
# type              0.00000
# public_repos      0.00000
# id                0.00000
# is_suspicious     0.00000
# public_gists      0.00000
# followers         0.00000
# created_at        0.00000
# blog              0.00000
# following         0.00000
# login             0.00000
# updated_at        0.00000
# dtype: float64
